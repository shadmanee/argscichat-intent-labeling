# %%
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from pathlib import Path

# %%
root = Path("..")

# %%
DATASET_DIR = root / "data" / "processed"
INPUT_DATASET_PATH = DATASET_DIR / "processed_df_0.csv"
OUTPUT_DATASET_PATH = DATASET_DIR / "processed_df_1.csv"
DATASET_DIR.exists(), INPUT_DATASET_PATH.exists() # have to be True
# Out:
# (True, True)

# %%
df = pd.read_csv(INPUT_DATASET_PATH)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   role             750 non-null    str
#  1   message_number   750 non-null    int64
#  2   sentence_number  750 non-null    int64
#  3   sentence         750 non-null    str
#  4   tag              750 non-null    str
#  5   dialogue_number  750 non-null    int64
# dtypes: int64(3), str(3)
# memory usage: 35.3 KB

# %%
df = df.sort_values(by=["dialogue_number", "message_number", "sentence_number"]).reset_index(drop=True)

# %%
# replacing multiple whitespaces with single + removing leading/training whitespaces
df["sentence_clean"] = df["sentence"].str.lower().str.replace(r"\s+", " ", regex=True).str.strip()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   role             750 non-null    str
#  1   message_number   750 non-null    int64
#  2   sentence_number  750 non-null    int64
#  3   sentence         750 non-null    str
#  4   tag              750 non-null    str
#  5   dialogue_number  750 non-null    int64
#  6   sentence_clean   750 non-null    str
# dtypes: int64(3), str(4)
# memory usage: 41.1 KB

# %%
starts = df.groupby("dialogue_number").head(1)

print(starts[["dialogue_number", "role", "message_number", "sentence_number", "sentence", "tag"]])
# Out:
#      dialogue_number           role  message_number  sentence_number  \
# 0                  0      Proponent               0                1
# 15                 1      Proponent               0                1
# 31                 2      Proponent               0                0
# 46                 3      Proponent               0                1
# 63                 4      Proponent               0                1
# 76                 5      Proponent               0                1
# 89                 6  Domain Expert               1                1
# 102                7      Proponent               0                0
# 114                8  Domain Expert               1                1
# 128                9      Proponent               0                0
# 143               10      Proponent               0                1
# 158               11  Domain Expert               1                1
# 183               12      Proponent               0                1
# 204               13      Proponent               0                1
# 217               14      Proponent               0                0
# 241               15      Proponent               0                0
# 259               16      Proponent               0                1
# 272               17      Proponent               0                1
# 292               18      Proponent               2                0
# 317               19      Proponent               0                0
# 347               20      Proponent               0                1
# 362               21  Domain Expert               1                1
# 378               22      Proponent               0                0
# 398               23      Proponent               0                0
# 411               24      Proponent               0                0
# 428               25      Proponent               0                2
# 445               26      Proponent               0                1
# 460               27      Proponent               0                0
# 480               28      Proponent               2                0
# 495               29      Proponent               0                0
# 511               30      Proponent               0                0
# 525               31      Proponent               0                0
# 543               32      Proponent               0                1
# 558               33      Proponent               0                1
# 574               34      Proponent               0                0
# 604               35      Proponent               0                0
# 626               36      Proponent               0                0
# 647               37      Proponent               2                0
# 670               38      Proponent               0                1
# 694               39      Proponent               0                0
# 718               40      Proponent               0                0
#
#                                               sentence             tag
# 0    What is the type of knowledge that is injected...        ask_info
# 15                          What is the article about?        ask_info
# 31                       Hi, what is this paper about?        ask_info
# 46   Can you give me a general overview of what is ...        ask_info
# 63   Can you provide to me some information about t...        ask_info
# 76                           What is this paper about?        ask_info
# 89   Is there something you want to know about the ...  ask_suggestion
# 102                        What is this article about?        ask_info
# 114  do you want to talk about multi-task residual ...  ask_suggestion
# 128                   Hello, what is this paper about?        ask_info
# 143                          What is this paper about?        ask_info
# 158  Do you want to know something about unfairness...  ask_suggestion
# 183                        What is this article about?        ask_info
# 204               Why is annotation projection useful?        ask_info
# 217    Hi, what exactly is meant by lexical inference?        ask_info
# 241  hello there, what exactly is the main contribu...        ask_info
# 259  What kind of knowledge does domain knowledge r...        ask_info
# 272  What is the constrained problem mentioned in t...        ask_info
# 292  Is this work about natural language processing...        ask_info
# 317     Hi, how is political parody defined the paper?        ask_info
# 347                          What is this paper about?        ask_info
# 362                                               Yes!      reply_info
# 378                       Hi, what is the paper about?        ask_info
# 398                what is the main idea of the paper?        ask_info
# 411                       Hi, interesting paper title.    give_opinion
# 428  Can you explain what is the main idea of the p...        ask_info
# 445                 Interesting question as the title.    give_opinion
# 460  Hello there, what are some examples for explic...        ask_info
# 480                           What is the paper about?        ask_info
# 495  Hi there, How do author suggest infusing quest...        ask_info
# 511           Hi, what is the subject of this article?        ask_info
# 525                      Hi, what is this paper about?        ask_info
# 543        Can you explain the main idea of the paper?        ask_info
# 558    What kind of deep learning methods did you use?        ask_info
# 574                       Hi, what is this work about?        ask_info
# 604  Hi, the title sounds interesting, can you tell...        ask_info
# 626        Hi, what are information-seeking questions?        ask_info
# 647                           What is the paper about?        ask_info
# 670                What is the main idea of the paper?        ask_info
# 694  Hello, could you please tell me what is Annota...        ask_info
# 718         What do you mean with low resource domain?        ask_info

# %%
df_temp = df.copy(deep=True)

# %%
df_temp["sentence"] = df_temp["sentence"].astype(str).str.strip()

empty_sentences = df_temp[df_temp["sentence"].eq("")]
print("Empty sentences:", len(empty_sentences))
# Out:
# Empty sentences: 0

# %%
duplicates = df_temp.duplicated(
    subset=["dialogue_number", "role", "message_number", "sentence_number", "sentence", "tag"]
)

print(df_temp[duplicates])
# these seem okay because they are different messages
# Out:
#           role  message_number  sentence_number      sentence         tag  \
# 160  Proponent               2                0  Yes, please.  reply_info
# 175  Proponent              10                0  Yes, please.  reply_info
#
#      dialogue_number sentence_clean
# 160               11   yes, please.
# 175               11   yes, please.

# %%
print(pd.crosstab(df_temp["role"], df_temp["tag"], normalize="index") * 100)
# Out:
# tag             ask_info  ask_rebuttal  ask_suggestion  give_opinion  \
# role
# Domain Expert   0.982801      6.879607        7.616708     11.793612
# Proponent      63.265306      6.122449        1.166181     21.865889
#
# tag            reply_info
# role
# Domain Expert   72.727273
# Proponent        7.580175

# %%
dist = pd.crosstab(df_temp["role"], df_temp["tag"], normalize="index") * 100

plt.figure(figsize=(10, 4))

ax = sns.heatmap(
    dist,
    annot=True,
    fmt=".1f",
    cmap="YlGnBu",
    linewidths=0.5,
    linecolor="white",
    cbar=True,
    cbar_kws={"label": "Percentage (%)"},
    vmin=0,
    vmax=100
)

plt.title("Intent-label distribution by role (%)", fontsize=13)
plt.xlabel("Tag")
plt.ylabel("Role")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
seq_lengths = df_temp.groupby("dialogue_number").size()

print(seq_lengths.describe())
print("Very short sequences:")
print(seq_lengths[seq_lengths <= 1])
# oh great no one word sequences XD
# Out:
# count    41.000000
# mean     18.292683
# std       5.163545
# min      12.000000
# 25%      15.000000
# 50%      16.000000
# 75%      21.000000
# max      32.000000
# dtype: float64
# Very short sequences:
# Series([], dtype: int64)

# %%
df.to_csv(OUTPUT_DATASET_PATH, index=False)
