# %%
import pandas as pd
from pathlib import Path

# %%
root = Path("..")

# %%
DATASET_DIR = root / "data" / "processed"
DATASET_PATH = DATASET_DIR / "processed_df_1.csv"
DATASET_DIR.exists(), DATASET_PATH.exists()
# Out:
# (True, True)

# %% [markdown]
# - Note: For HMM, no external features are required?

# %% [markdown]
# ### 1. Surface features:
#
# - average sentence length
# - average word length (are they using big words? that's important? XDD)
# - number of unique words
# - number of stopwords
# - ratio of stopwords to total words
# - OOV word count/ratio (not sure if it can be informative)
#
# ### 2. Lexical and morphological features:
#
# - bag of words
# - tfidf scores per term (how to structure?)
# - word n-gram frequencies
#
# <b>TO BE CONTINUED...</b>
